# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import praw
#       3 reddit = praw.Reddit(
#       4     client_id="O_TEU_CLIENT_ID",
#       5     client_secret="O_TEU_CLIENT_SECRET",
#       6     user_agent="O_TEU_USER_AGENT",
#       7 )
#
# ModuleNotFoundError: No module named 'praw'
